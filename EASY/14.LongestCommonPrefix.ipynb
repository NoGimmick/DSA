# %% [markdown]
# # Longest Common Prefix
#
# Write a function to find the longest common prefix string amongst an array of strings.
#
#
# If there is no common prefix, return an empty string "".
#
# **Example 1:**
#
# ```
# Input: `strs = ["flower","flow","flight"]`
# ```
#
# **Output:** `"fl"`
#
# **Example 2:**
#
# ```
# Input: strs = ["dog","racecar","car"]
# ```
#
# **Output:** `""`
#
# Explanation: There is no common prefix among the input strings.

# %%
def longestCommonPrefix(strs):
    if not strs:
        return ""

    result = strs[0]

    for word in strs[1:]:
        i = 0

        while i < len(result) and i < len(word):
            if result[i] != word[i]:
                break
            i += 1

        result = result[:i]

        if result == "":
            return ""

    return result

# %%
String = ["flower","flow","flight", 'flicker', 'flush']

def Prefix(String):

    if not String:
        return ''

    result = String[0]

    for word in String[1:]:
        i = 0
        while i < len(word) and i < len(result):

            if result[i] != word[i]:
                break

            i += 1

            result = result[:i]

            if result == '':
                return ''
        
    return result



        
print (Prefix(String))
# Out:
# f

# %%
class Solution:
    def longestCommonPrefix(self, strs: List[str]) -> str:
        if len(strs) == 0:
            return ""
        prefix = strs[0]
        for i in range(1, len(strs)):
            while strs[i].find(prefix) != 0:
                prefix = prefix[0 : len(prefix) - 1]
                if prefix == "":
                    return ""
        return prefix
